# %% [markdown]
# # ASSIGNMENT 2

# %% [markdown]
# # Loading dataset

# %%
import pandas as pd
file = r'C:/Users/User/Downloads/Restaurant reviews.csv'
df = pd.read_csv(file)
df.head(30)# prints only first 30 values from the data
# Out:
#          Restaurant              Reviewer  \
# 0   Beyond Flavours     Rusha Chakraborty
# 1   Beyond Flavours  Anusha Tirumalaneedi
# 2   Beyond Flavours       Ashok Shekhawat
# 3   Beyond Flavours        Swapnil Sarkar
# 4   Beyond Flavours                Dileep
# 5   Beyond Flavours         Nagabhavani K
# 6   Beyond Flavours       Jamuna Bhuwalka
# 7   Beyond Flavours             Sandhya S
# 8   Beyond Flavours          Akash Thorat
# 9   Beyond Flavours        Smarak Patnaik
# 10  Beyond Flavours      Saubhagya Bhuyan
# 11  Beyond Flavours            Srivaths07
# 12  Beyond Flavours           Kunj Mishra
# 13  Beyond Flavours     Pradeep Vetapalem
# 14  Beyond Flavours         Kankaria.ritu
# 15  Beyond Flavours          Abhay Sharma
# 16  Beyond Flavours       Shubham Jaiswal
# 17  Beyond Flavours     Srijani Mukherjee
# 18  Beyond Flavours           Hari Jangam
# 19  Beyond Flavours           Suneet Soni
# 20  Beyond Flavours     Little Chef Chika
# ...

# %% [markdown]
# # prints the complete data values

# %%
df# prints the complete data values
# Out:
#             Restaurant              Reviewer  \
# 0      Beyond Flavours     Rusha Chakraborty
# 1      Beyond Flavours  Anusha Tirumalaneedi
# 2      Beyond Flavours       Ashok Shekhawat
# 3      Beyond Flavours        Swapnil Sarkar
# 4      Beyond Flavours                Dileep
# ...                ...                   ...
# 9995  Chinese Pavilion      Abhishek Mahajan
# 9996  Chinese Pavilion        Sharad Agrawal
# 9997  Chinese Pavilion             Ramandeep
# 9998  Chinese Pavilion       Nayana Shanbhag
# 9999  Chinese Pavilion      Bhargava Krishna
#
#                                                  Review Rating  \
# 0     The ambience was good, food was quite good . h...      5
# 1     Ambience is too good for a pleasant evening. S...      5
# 2     A must try.. great food great ambience. Thnx f...      5
# 3     Soumen das and Arun was a great guy. Only beca...      5
# 4     Food is good.we ordered Kodi drumsticks and ba...      5
# ...

# %% [markdown]
# # Displaying just a fraction of data

# %%
df.sample(frac=0.2)# It just takes randomly 20% of the data and displays it
# Out:
#                                Restaurant                   Reviewer  \
# 1568                                  KFC                    Ganessh
# 7047           Urban Asia - Kitchen & Bar              Srikanth Goud
# 3610  Banana Leaf Multicuisine Restaurant                        Rag
# 5916                            KS Bakers               Sunny Daniel
# 5061                        Gal Punjab Di              Unnatirocks95
# ...                                   ...                        ...
# 292                              Flechazo                     Nikhil
# 2234                               B-Dubs                Kiran Kumar
# 9089                         Arena Eleven                        NaN
# 2654               Mustang Terrace Lounge                Akhila Akhi
# 9054                         Arena Eleven  Raja Gopal Reddy Chereddy
#
#                                                  Review Rating  \
# 1568                                                gud      4
# ...

# %% [markdown]
# # prints only column names

# %%
df.columns# prints only column names
# Out:
# Index(['Restaurant', 'Reviewer', 'Review', 'Rating', 'Metadata', 'Time',
#        'Pictures', '7514'],
#       dtype='object')

# %% [markdown]
# # gives the data type of each column

# %%
df.dtypes# gives the data type of each column
# Out:
# Restaurant     object
# Reviewer       object
# Review         object
# Rating         object
# Metadata       object
# Time           object
# Pictures        int64
# 7514          float64
# dtype: object

# %% [markdown]
# # gives the complete information about the dataset including null and non null values

# %%
df.info()#gives the complete information about the dataset including null and non null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Restaurant  10000 non-null  object
#  1   Reviewer    9962 non-null   object
#  2   Review      9955 non-null   object
#  3   Rating      9962 non-null   object
#  4   Metadata    9962 non-null   object
#  5   Time        9962 non-null   object
#  6   Pictures    10000 non-null  int64
#  7   7514        1 non-null      float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 625.1+ KB

# %% [markdown]
# # gives us a overall values of the given dataset

# %%
df.describe()# gives us a overall values of the given dataset
# Out:
#            Pictures    7514
# count  10000.000000     1.0
# mean       0.748600  2447.0
# std        2.570381     NaN
# min        0.000000  2447.0
# 25%        0.000000  2447.0
# 50%        0.000000  2447.0
# 75%        0.000000  2447.0
# max       64.000000  2447.0

# %% [markdown]
# # prints the length of the speech along with the description

# %%
df['length'] = df['Review'].str.len()
df.describe()#prints the length of the speech along with the description
# Out:
#            Pictures    7514       length
# count  10000.000000     1.0  9955.000000
# mean       0.748600  2447.0   279.774485
# std        2.570381     NaN   338.598799
# min        0.000000  2447.0     1.000000
# 25%        0.000000  2447.0   144.000000
# 50%        0.000000  2447.0   189.000000
# 75%        0.000000  2447.0   321.000000
# max       64.000000  2447.0  5212.000000

# %% [markdown]
# # gives stats about the data

# %%
df.describe(include='O')# gives stats about the data
# Out:
#              Restaurant     Reviewer Review Rating  Metadata             Time
# count             10000         9962   9955   9962      9962             9962
# unique              100         7446   9364     10      2477             9782
# top     Beyond Flavours  Parijat Ray   good      5  1 Review  7/29/2018 20:34
# freq                100           13    237   3832       919                3

# %% [markdown]
# # checks for the missing data from the total dataset

# %%
df.isna().sum()# checks for the missing data from the total dataset
# Out:
# Restaurant       0
# Reviewer        38
# Review          45
# Rating          38
# Metadata        38
# Time            38
# Pictures         0
# 7514          9999
# length          45
# dtype: int64

# %% [markdown]
# # Removing null values from the dataset

# %%
df['Review'].fillna('unkown',inplace=True)
df['Rating'].fillna('unkown',inplace=True)
df.isna().sum()# changes null or NAn values as unknown
# Out:
# Restaurant       0
# Reviewer        38
# Review           0
# Rating           0
# Metadata        38
# Time            38
# Pictures         0
# 7514          9999
# length          45
# dtype: int64

# %% [markdown]
# # changes the text in the specified columns into upper cases

# %%
df['Review']=df['Review'].str.upper()
df['Rating']=df['Rating'].str.upper()
df['Reviewer']=df['Reviewer'].str.upper()
df#changes the text in the specified columns into upper cases
# Out:
#             Restaurant              Reviewer  \
# 0      Beyond Flavours     RUSHA CHAKRABORTY
# 1      Beyond Flavours  ANUSHA TIRUMALANEEDI
# 2      Beyond Flavours       ASHOK SHEKHAWAT
# 3      Beyond Flavours        SWAPNIL SARKAR
# 4      Beyond Flavours                DILEEP
# ...                ...                   ...
# 9995  Chinese Pavilion      ABHISHEK MAHAJAN
# 9996  Chinese Pavilion        SHARAD AGRAWAL
# 9997  Chinese Pavilion             RAMANDEEP
# 9998  Chinese Pavilion       NAYANA SHANBHAG
# 9999  Chinese Pavilion      BHARGAVA KRISHNA
#
#                                                  Review Rating  \
# 0     THE AMBIENCE WAS GOOD, FOOD WAS QUITE GOOD . H...      5
# 1     AMBIENCE IS TOO GOOD FOR A PLEASANT EVENING. S...      5
# 2     A MUST TRY.. GREAT FOOD GREAT AMBIENCE. THNX F...      5
# 3     SOUMEN DAS AND ARUN WAS A GREAT GUY. ONLY BECA...      5
# 4     FOOD IS GOOD.WE ORDERED KODI DRUMSTICKS AND BA...      5
# ...

# %% [markdown]
# # displays all the review with good

# %%
df[df['Review'].str.contains('GOOD')]
#displays all the smoker with yes
# Out:
#             Restaurant                 Reviewer  \
# 0      Beyond Flavours        RUSHA CHAKRABORTY
# 1      Beyond Flavours     ANUSHA TIRUMALANEEDI
# 3      Beyond Flavours           SWAPNIL SARKAR
# 4      Beyond Flavours                   DILEEP
# 5      Beyond Flavours            NAGABHAVANI K
# ...                ...                      ...
# 9989  Chinese Pavilion          SWARNABHA MITRA
# 9991  Chinese Pavilion  KRISHNA TEJA RATNAKARAM
# 9995  Chinese Pavilion         ABHISHEK MAHAJAN
# 9997  Chinese Pavilion                RAMANDEEP
# 9998  Chinese Pavilion          NAYANA SHANBHAG
#
#                                                  Review Rating  \
# 0     THE AMBIENCE WAS GOOD, FOOD WAS QUITE GOOD . H...      5
# 1     AMBIENCE IS TOO GOOD FOR A PLEASANT EVENING. S...      5
# 3     SOUMEN DAS AND ARUN WAS A GREAT GUY. ONLY BECA...      5
# 4     FOOD IS GOOD.WE ORDERED KODI DRUMSTICKS AND BA...      5
# 5     AMBIANCE IS GOOD, SERVICE IS GOOD, FOOD IS APR...      5
# ...

# %% [markdown]
# # A plot for the length column

# %%
df['length'].plot()
# Out:
# <Axes: >

# %% [markdown]
# # BOXPLOT

# %%
df['length'].plot(kind='box', vert=False)
# Out:
# <Axes: >

# %% [markdown]
# # HISTOGRAM

# %%
df['length'].plot(kind='hist', bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Box plot for lenth and country columns

# %%
import seaborn as sns 
where = df['Review'].isin(['GOOD', 'FOOD', 'PLEASANT', 'CHINESE','MUST','PLACE','BAD'])
g = sns.catplot(data=df[where], x="Review", y="length", kind='box')
g.fig.set_size_inches(10, 8)
# Out:
# C:\Users\User\anaconda3\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # REGEX 2

# %%
import regex as re# imports the regex

def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)

# %%
testtext = "EE saala cup namde 2024! www.dvd.assam"
testtokens = tokenize(testtext)# tokenizes the given sample
 
print(testtokens)
# Out:
# ['EE', 'saala', 'cup', 'namde', 'www', 'dvd', 'assam']

# %% [markdown]
# # STOPWORDS

# %%
import nltk 
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# imports the inbuilt stopwords depending upon the language specified
# Out:
# {'couldn', 'she', 'by', 'needn', 'our', "you're", 'now', 'don', 'll', 'him', 'further', 'my', 'who', 'where', 'own', 'whom', 've', 'having', 'and', 'up', 'each', "wouldn't", "won't", 'its', 'mustn', 'you', 'an', 'those', 'against', 'that', "doesn't", "hasn't", "mustn't", 'her', 'has', 'down', "don't", 'herself', 'being', 'did', 'because', 'as', 'didn', "hadn't", "haven't", 'do', "needn't", "you've", 'into', 'weren', 'his', 'these', 'hasn', 'haven', 'such', 'under', 'how', 'some', 'their', 'shouldn', 'were', 'wasn', "you'd", 'during', 'themselves', "wasn't", 'while', 'once', 'hadn', "couldn't", 'me', 'both', "aren't", "mightn't", 'very', 'same', 'aren', 'ours', 'doing', 'we', 'have', 'out', 'himself', 'yours', 'at', 'is', 'not', 'i', "didn't", 'but', 'y', 't', 'too', 'in', 'here', 'won', 'or', 's', 'had', "weren't", 'yourselves', 'on', 'will', 'they', "that'll", 'then', 'most', 'if', 'again', 'be', 'does', "shouldn't", 'isn', "shan't", 'mightn', 'are', 'from', 'he', 'wouldn', 'than', 
# ...

# %% [markdown]
# # removing the stopwords

# %%
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]
#Just testing it
cleantokens= remove_stop(testtokens)
print(cleantokens)
#removing the stopwords
# Out:
# ['EE', 'saala', 'cup', 'namde', 'www', 'dvd', 'assam']

# %% [markdown]
# # Initialization of the Pipeline

# %%
pipeline = [str.lower, tokenize, remove_stop]

def prepare(Review, pipeline):
    tokens = Review
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens

# %%
df['tokens'] = df['Review'].apply(prepare, pipeline=pipeline)# runs the pipeline

# %% [markdown]
# # Counting the tokens in the dataset

# %%
df['num_tokens'] = df['tokens'].map(len)
df.tail()
# Out:
#             Restaurant          Reviewer  \
# 9995  Chinese Pavilion  ABHISHEK MAHAJAN
# 9996  Chinese Pavilion    SHARAD AGRAWAL
# 9997  Chinese Pavilion         RAMANDEEP
# 9998  Chinese Pavilion   NAYANA SHANBHAG
# 9999  Chinese Pavilion  BHARGAVA KRISHNA
#
#                                                  Review Rating  \
# 9995  MADHUMATHI MAHAJAN WELL TO START WITH NICE COU...      3
# 9996  THIS PLACE HAS NEVER DISAPPOINTED US.. THE FOO...    4.5
# 9997  BAD RATING IS MAINLY BECAUSE OF "CHICKEN BONE ...    1.5
# 9998  I PERSONALLY LOVE AND PREFER CHINESE FOOD. HAD...      4
# 9999  CHECKED IN HERE TO TRY SOME DELICIOUS CHINESE ...    3.5
#
#                           Metadata             Time  Pictures  7514  length  \
# 9995     53 Reviews , 54 Followers    6/5/2016 0:08         0   NaN  1024.0
# 9996      2 Reviews , 53 Followers   6/4/2016 22:01         0   NaN   320.0
# 9997    65 Reviews , 423 Followers   6/3/2016 10:37         3   NaN  1555.0
# ...

# %% [markdown]
# # WORD FREQUENCY ANALYSIS
# ## USING THE COUNTER

# %%
from collections import Counter

tokens = tokenize("She likes my cats and my cats like my sofa.")

testcount= Counter(tokens)
print(testcount)
# testing the counter
# Out:
# Counter({'my': 3, 'cats': 2, 'She': 1, 'likes': 1, 'and': 1, 'like': 1, 'sofa': 1})

# %% [markdown]
# # adding new data for the already existing count

# %%
more_tokens = tokenize("She likes dogs and cats.")# adding new data for the already existing count
testcount.update(more_tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 3, 'She': 2, 'likes': 2, 'and': 2, 'like': 1, 'sofa': 1, 'dogs': 1})

# %%
counter = Counter()
df['tokens'].map(counter.update)# using counter on our dataset
print(counter.most_common(5))
# Out:
# [('good', 7226), ('food', 6574), ('place', 5731), ('service', 3184), ('chicken', 3094)]

# %% [markdown]
# # specifying the frequency of the word count

# %%
freq_df = pd.DataFrame.from_dict(counter, orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1')# specifying the frequency of the word count
freq_df.index.name = 'token'

# %% [markdown]
# # sorting the data and displaying it

# %%
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(20)
# sorting the data and displaying it
# Out:
#             freq
# token
# good        7226
# food        6574
# place       5731
# service     3184
# chicken     3094
# taste       2271
# ordered     2177
# ambience    2070
# great       1977
# one         1935
# really      1671
# time        1609
# also        1600
# nice        1503
# like        1453
# best        1449
# biryani     1360
# staff       1325
# try         1296
# restaurant  1281

# %%
freq_df.describe()# stats
# Out:
#                freq
# count  15393.000000
# mean      17.672773
# std      125.359836
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        5.000000
# max     7226.000000

# %% [markdown]
# # BAR CHART FOR TOKEN AND FREQUENCY¶

# %%
ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(12,8))
ax.invert_yaxis()
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words')
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # WORD CLOUD

# %%
from wordcloud import WordCloud
from matplotlib import pyplot as plt

text = df.query("Pictures==0 and Review=='GOOD'")['Review'].values[0]

plt.figure(figsize=(14, 7)) ###
wc = WordCloud(max_words=100, stopwords=stopwords)
wc.generate(text)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
wc = WordCloud(background_color='white', width = 300, height=300, max_words=100, margin=2)
wc.fit_words(freq_df['freq'].to_dict() )
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wc)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()
